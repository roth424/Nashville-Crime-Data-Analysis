# %%
#import packages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#import sqlite3 as sql
import folium
import gmaps
from datetime import datetime

# %matplotlib inline

# %%
police_2016 = pd.read_csv('Metro_Nashville_Davidson_County_Calls_For_Police_Service__2016_.csv')
police_2016.head()
# Out:
#      Event Number           Call Received  Complaint Number Shift Tencode  \
# 0  PD201600000001  01/01/2016 12:00:00 AM       20160000002     C      96
# 1  PD201600000002  01/01/2016 12:00:00 AM       20160000003     C      96
# 2  PD201600000003  01/01/2016 12:00:00 AM       20160000017     C      45
# 3  PD201600000004  01/01/2016 12:00:00 AM                 0     C      83
# 4  PD201600000005  01/01/2016 12:00:00 AM       20160000005     C      96
#
#                   Tencode Description Tencode Suffix  \
# 0                      Business Check            NaN
# 1                      Business Check            NaN
# 2  Vehicle Accident - Property Damage              P
# 3                         Shots Fired              P
# 4                      Business Check            NaN
#
#   Tencode Suffix Description  Disposition Code   Disposition Description  \
# 0                        NaN                12  LOCATION/BUILDING SECURE
# 1                        NaN                12  LOCATION/BUILDING SECURE
# 2                   PROGRESS                 1     M.P.D. REPORT COMPLED
# 3                   PROGRESS                11      DISREGARD / SIGNAL 9
# 4                        NaN                12  LOCATION/BUILDING SECURE
#
#     Block                  Street Name Unit Dispatched Sector  Zone  \
# 0   300.0                   HERRON DR             311C      S  11.0
# 1   500.0                     MAIN ST             213C      E  11.0
# 2     0.0  EDMONDSON PKE & MCMURRAY DR            835C     MT  33.0
# 3   500.0                    S 5TH ST              NaN      E  11.0
# 4  1100.0                     BELL RD             333C      S  25.0
#
#    Reporting Area (RPA)  Latitude  Longitude    Mapped Location
# 0                8125.0    36.133    -86.752  (36.133, -86.752)
# 1                1113.0    36.173    -86.764  (36.173, -86.764)
# 2                8657.0    36.055    -86.743  (36.055, -86.743)
# 3                1011.0    36.167    -86.762  (36.167, -86.762)
# 4                8721.0    36.046    -86.666  (36.046, -86.666)

# %%
police_2016.shape
# Out:
# (1127959, 19)

# %%
sns.heatmap(police_2016.isnull(), cbar=False)

# %%
reduced_police_2016=police_2016[["Event Number","Call Received","Shift","Tencode","Tencode Description","Disposition Code","Disposition Description","Unit Dispatched","Sector","Latitude","Longitude","Mapped Location"]]
reduced_police_2016.head()
# Out:
#      Event Number           Call Received Shift Tencode  \
# 0  PD201600000001  01/01/2016 12:00:00 AM     C      96
# 1  PD201600000002  01/01/2016 12:00:00 AM     C      96
# 2  PD201600000003  01/01/2016 12:00:00 AM     C      45
# 3  PD201600000004  01/01/2016 12:00:00 AM     C      83
# 4  PD201600000005  01/01/2016 12:00:00 AM     C      96
#
#                   Tencode Description  Disposition Code  \
# 0                      Business Check                12
# 1                      Business Check                12
# 2  Vehicle Accident - Property Damage                 1
# 3                         Shots Fired                11
# 4                      Business Check                12
#
#     Disposition Description Unit Dispatched Sector  Latitude  Longitude  \
# 0  LOCATION/BUILDING SECURE            311C      S    36.133    -86.752
# 1  LOCATION/BUILDING SECURE            213C      E    36.173    -86.764
# 2     M.P.D. REPORT COMPLED            835C     MT    36.055    -86.743
# 3      DISREGARD / SIGNAL 9             NaN      E    36.167    -86.762
# 4  LOCATION/BUILDING SECURE            333C      S    36.046    -86.666
#
#      Mapped Location
# 0  (36.133, -86.752)
# 1  (36.173, -86.764)
# 2  (36.055, -86.743)
# 3  (36.167, -86.762)
# 4  (36.046, -86.666)

# %%
reduced_police_2016.shape
# Out:
# (1127959, 12)

# %%
sns.heatmap(reduced_police_2016.isnull(), cbar=False)

# %%
new_police_2016=reduced_police_2016.dropna(how='any')
new_police_2016
# Out:
#            Event Number           Call Received Shift Tencode  \
# 0        PD201600000001  01/01/2016 12:00:00 AM     C      96
# 1        PD201600000002  01/01/2016 12:00:00 AM     C      96
# 2        PD201600000003  01/01/2016 12:00:00 AM     C      45
# 4        PD201600000005  01/01/2016 12:00:00 AM     C      96
# 5        PD201600000006  01/01/2016 12:00:00 AM     C      46
# 7        PD201600000008  01/01/2016 12:02:00 AM     C      83
# 11       PD201600000012  01/01/2016 12:02:00 AM     C      43
# 12       PD201600000013  01/01/2016 12:02:00 AM     C      93
# 13       PD201600000015  01/01/2016 12:03:00 AM     C      83
# 14       PD201600000016  01/01/2016 12:03:00 AM     C      83
# 16       PD201600000019  01/01/2016 12:05:00 AM     C      83
# 17       PD201600000022  01/01/2016 12:05:00 AM     C      83
# 18       PD201600000023  01/01/2016 12:05:00 AM     C      83
# 19       PD201600000024  01/01/2016 12:06:00 AM     C      42
# 22       PD201600000027  01/01/2016 12:07:00 AM     C      43
# 23       PD201600000028  01/01/2016 12:07:00 AM     C      83
# 24       PD201600000029  01/01/2016 12:07:00 AM     C      83
# 25       PD201600000030  01/01/2016 12:08:00 AM     C      83
# 27       PD201600000033  01/01/2016 12:08:00 AM     C      83
# 29       PD201600000034  01/01/2016 12:09:00 AM     C      83
# 31       PD201600000036  01/01/2016 12:10:00 AM     C      83
# 32       PD201600000037  01/01/2016 12:10:00 AM     C      83
# 33       PD201600000039  01/01/2016 12:11:00 AM     C      83
# 34       PD201600000040  01/01/2016 12:11:00 AM     C      83
# 35       PD201600000041  01/01/2016 12:11:00 AM     C      83
# 36       PD201600000042  01/01/2016 12:12:00 AM     C      83
# 37       PD201600000043  01/01/2016 12:12:00 AM     C      83
# 39       PD201600000045  01/01/2016 12:12:00 AM     C      83
# 40       PD201600000046  01/01/2016 12:12:00 AM     C      83
# 41       PD201600000047  01/01/2016 12:13:00 AM     C      44
# ...                 ...                     ...   ...     ...
# 1127819  PD201601315863  12/31/2016 10:32:00 PM     B      44
# 1127820  PD201601315864  12/31/2016 10:32:00 PM     B      93
# 1127821  PD201601315865  12/31/2016 10:32:00 PM     B      83
# 1127822  PD201601315867  12/31/2016 10:33:00 PM     B      93
# 1127823  PD201601315868  12/31/2016 10:33:00 PM     B      70
# 1127827  PD201601315873  12/31/2016 10:35:00 PM     B      93
# 1127828  PD201601315875  12/31/2016 10:36:00 PM     B      96
# 1127829  PD201601315877  12/31/2016 10:39:00 PM     B      71
# 1127830  PD201601315878  12/31/2016 10:40:00 PM     B      46
# 1127831  PD201601315879  12/31/2016 10:40:00 PM     B      49
# 1127832  PD201601315880  12/31/2016 10:40:00 PM     B      45
# 1127833  PD201601315881  12/31/2016 10:40:00 PM     B      88
# 1127834  PD201601315885  12/31/2016 10:43:00 PM     B      96
# 1127835  PD201601315886  12/31/2016 10:44:00 PM     B      83
# 1127836  PD201601315887  12/31/2016 10:44:00 PM     B      88
# 1127837  PD201601315888  12/31/2016 10:45:00 PM     B      57
# 1127838  PD201601315889  12/31/2016 10:46:00 PM     B      96
# 1127839  PD201601315890  12/31/2016 10:47:00 PM     B      93
# 1127840  PD201601315891  12/31/2016 10:48:00 PM     B      93
# 1127841  PD201601315892  12/31/2016 10:48:00 PM     B      83
# 1127842  PD201601315893  12/31/2016 10:49:00 PM     B      71
# 1127843  PD201601315894  12/31/2016 10:49:00 PM     B      96
# 1127846  PD201601315897  12/31/2016 10:51:00 PM     B      57
# 1127847  PD201601315900  12/31/2016 10:52:00 PM     B      43
# 1127848  PD201601315901  12/31/2016 10:52:00 PM     B      44
# 1127850  PD201601315904  12/31/2016 10:54:00 PM     B      96
# 1127851  PD201601315906  12/31/2016 10:56:00 PM     B      93
# 1127852  PD201601315908  12/31/2016 10:56:00 PM     B      40
# 1127853  PD201601315909  12/31/2016 10:56:00 PM     B      96
# 1127854  PD201601315910  12/31/2016 10:57:00 PM     B      96
#
#                                  Tencode Description  Disposition Code  \
# 0                                     Business Check                12
# 1                                     Business Check                12
# 2                 Vehicle Accident - Property Damage                 1
# 4                                     Business Check                12
# 5                 Vehicle Accident - Personal Injury                11
# 7                                        Shots Fired                 5
# 11       Want Officer for Investigation / Assistance                 6
# 12                                 Traffic Violation                 9
# 13                                       Shots Fired                10
# 14                                       Shots Fired                11
# 16                                       Shots Fired                 5
# 17                                       Shots Fired                 6
# 18                                       Shots Fired                 6
# 19                                Intoxicated Person                 2
# 22       Want Officer for Investigation / Assistance                 2
# 23                                       Shots Fired                11
# 24                                       Shots Fired                 5
# 25                                       Shots Fired                11
# 27                                       Shots Fired                10
# 29                                       Shots Fired                 5
# 31                                       Shots Fired                10
# 32                                       Shots Fired                10
# 33                                       Shots Fired                 6
# 34                                       Shots Fired                10
# 35                                       Shots Fired                 5
# 36                                       Shots Fired                 4
# 37                                       Shots Fired                11
# 39                                       Shots Fired                 5
# 40                                       Shots Fired                10
# 41                                 Disorderly Person                 4
# ...                                              ...               ...
# 1127819                            Disorderly Person                11
# 1127820                            Traffic Violation                 9
# 1127821                                  Shots Fired                 6
# 1127822                            Traffic Violation                 9
# 1127823                         Burglary - Residence                 6
# 1127827                            Traffic Violation                 9
# 1127828                               Business Check                12
# 1127829                     Burglary - Non-Residence                11
# 1127830           Vehicle Accident - Personal Injury                11
# 1127831                Vehicle Blocking Right of Way                 3
# 1127832           Vehicle Accident - Property Damage                11
# 1127833                 Investigate 911 Hang-Up Call                 5
# 1127834                               Business Check                12
# 1127835                                  Shots Fired                10
# 1127836                 Investigate 911 Hang-Up Call                11
# 1127837                              Fight / Assault                 5
# 1127838                               Business Check                12
# 1127839                            Traffic Violation                 6
# 1127840                            Traffic Violation                 6
# 1127841                                  Shots Fired                11
# 1127842                     Burglary - Non-Residence                12
# 1127843                               Business Check                 6
# 1127846                              Fight / Assault                 6
# 1127847  Want Officer for Investigation / Assistance                 5
# 1127848                            Disorderly Person                 9
# 1127850                               Business Check                11
# 1127851                            Traffic Violation                 9
# 1127852                            Suspicious Person                 5
# 1127853                               Business Check                12
# 1127854                               Business Check                12
#
#                Disposition Description Unit Dispatched Sector  Latitude  \
# 0             LOCATION/BUILDING SECURE            311C      S    36.133
# 1             LOCATION/BUILDING SECURE            213C      E    36.173
# 2                M.P.D. REPORT COMPLED            835C     MT    36.055
# 4             LOCATION/BUILDING SECURE            333C      S    36.046
# 5                 DISREGARD / SIGNAL 9            333C      S    36.054
# 7                      GONE ON ARRIVAL            613C      N    36.179
# 11                 ASSISTED OTHER UNIT            213C      E    36.166
# 12                      SUBJECT WARNED            721C      M    36.267
# 13                         NO RESPONSE            330C      S    36.072
# 14                DISREGARD / SIGNAL 9            711C      M    36.235
# 16                     GONE ON ARRIVAL            625C      N    36.238
# 17                 ASSISTED OTHER UNIT            2F21      E    36.180
# 18                 ASSISTED OTHER UNIT            221C      E    36.197
# 19       ARREST, CUSTODIAL OR CITATION           SQUAD      C    36.163
# 22       ARREST, CUSTODIAL OR CITATION            423C      C    36.154
# 23                DISREGARD / SIGNAL 9            110C      W    36.156
# 24                     GONE ON ARRIVAL            627C      N    36.228
# 25                DISREGARD / SIGNAL 9            627C      N    36.234
# 27                         NO RESPONSE            217C      E    36.202
# 29                     GONE ON ARRIVAL            523C      H    36.178
# 31                         NO RESPONSE            715C      M    36.276
# 32                         NO RESPONSE            715C      M    36.279
# 33                 ASSISTED OTHER UNIT            2F33      E    36.194
# 34                         NO RESPONSE            713C      M    36.234
# 35                     GONE ON ARRIVAL            533C      H    36.092
# 36                    ASSISTED CITIZEN            533C      H    36.078
# 37                DISREGARD / SIGNAL 9            821C     MT    36.158
# 39                     GONE ON ARRIVAL            811C     MT    36.073
# 40                         NO RESPONSE            715C      M    36.269
# 41                    ASSISTED CITIZEN            515C      H    36.218
# ...                                ...             ...    ...       ...
# 1127819           DISREGARD / SIGNAL 9            612B      N    36.187
# 1127820                 SUBJECT WARNED            227B      E    36.204
# 1127821            ASSISTED OTHER UNIT            813C     MT    36.141
# 1127822                 SUBJECT WARNED            4F24      C    36.152
# 1127823            ASSISTED OTHER UNIT            217C      E    36.203
# 1127827                 SUBJECT WARNED            4F23      C    36.152
# 1127828       LOCATION/BUILDING SECURE            4F22      C    36.167
# 1127829           DISREGARD / SIGNAL 9            511C      H    36.147
# 1127830           DISREGARD / SIGNAL 9            333B      S    36.030
# 1127831             CITATION - TRAFFIC            2M72      C    36.171
# 1127832           DISREGARD / SIGNAL 9            825C     MT    36.121
# 1127833                GONE ON ARRIVAL            223C      E    36.214
# 1127834       LOCATION/BUILDING SECURE            4F24      C    36.151
# 1127835                    NO RESPONSE            533C      H    36.143
# 1127836           DISREGARD / SIGNAL 9            835C     MT    36.058
# 1127837                GONE ON ARRIVAL            810C     MT    36.149
# 1127838       LOCATION/BUILDING SECURE            4F22      C    36.156
# 1127839            ASSISTED OTHER UNIT            413C      C    36.168
# 1127840            ASSISTED OTHER UNIT            5273      E    36.168
# 1127841           DISREGARD / SIGNAL 9            621C      N    36.228
# 1127842       LOCATION/BUILDING SECURE            331C      S    36.056
# 1127843            ASSISTED OTHER UNIT            4F22      C    36.152
# 1127846            ASSISTED OTHER UNIT            711C      M    36.259
# 1127847                GONE ON ARRIVAL            227C      E    36.189
# 1127848                 SUBJECT WARNED             ST8      C    36.174
# 1127850           DISREGARD / SIGNAL 9            423C      C    36.152
# 1127851                 SUBJECT WARNED            212C      E    36.205
# 1127852                GONE ON ARRIVAL            523C      H    36.258
# 1127853       LOCATION/BUILDING SECURE            421C      C    36.157
# 1127854       LOCATION/BUILDING SECURE            415C      C    36.167
#
#          Longitude    Mapped Location
# 0          -86.752  (36.133, -86.752)
# 1          -86.764  (36.173, -86.764)
# 2          -86.743  (36.055, -86.743)
# 4          -86.666  (36.046, -86.666)
# 5          -86.619  (36.054, -86.619)
# 7          -86.818  (36.179, -86.818)
# 11         -86.760   (36.166, -86.76)
# 12         -86.746  (36.267, -86.746)
# 13         -86.603  (36.072, -86.603)
# 14         -86.766  (36.235, -86.766)
# 16         -86.808  (36.238, -86.808)
# 17         -86.772   (36.18, -86.772)
# 18         -86.758  (36.197, -86.758)
# 19         -86.777  (36.163, -86.777)
# 22         -86.778  (36.154, -86.778)
# 23         -86.836  (36.156, -86.836)
# 24         -86.800    (36.228, -86.8)
# 25         -86.792  (36.234, -86.792)
# 27         -86.731  (36.202, -86.731)
# 29         -86.598  (36.178, -86.598)
# 31         -86.706  (36.276, -86.706)
# 32         -86.707  (36.279, -86.707)
# 33         -86.760   (36.194, -86.76)
# 34         -86.779  (36.234, -86.779)
# 35         -86.646  (36.092, -86.646)
# 36         -86.631  (36.078, -86.631)
# 37         -86.801  (36.158, -86.801)
# 39         -86.726  (36.073, -86.726)
# 40         -86.683  (36.269, -86.683)
# 41         -86.697  (36.218, -86.697)
# ...            ...                ...
# 1127819    -86.810   (36.187, -86.81)
# 1127820    -86.738  (36.204, -86.738)
# 1127821    -86.821  (36.141, -86.821)
# 1127822    -86.769  (36.152, -86.769)
# 1127823    -86.714  (36.203, -86.714)
# 1127827    -86.769  (36.152, -86.769)
# 1127828    -86.767  (36.167, -86.767)
# 1127829    -86.676  (36.147, -86.676)
# 1127830    -86.646   (36.03, -86.646)
# 1127831    -86.783  (36.171, -86.783)
# 1127832    -86.755  (36.121, -86.755)
# 1127833    -86.762  (36.214, -86.762)
# 1127834    -86.781  (36.151, -86.781)
# 1127835    -86.641  (36.143, -86.641)
# 1127836    -86.740   (36.058, -86.74)
# 1127837    -86.798  (36.149, -86.798)
# 1127838    -86.763  (36.156, -86.763)
# 1127839    -86.770   (36.168, -86.77)
# 1127840    -86.762  (36.168, -86.762)
# 1127841    -86.796  (36.228, -86.796)
# 1127842    -86.715  (36.056, -86.715)
# 1127843    -86.770   (36.152, -86.77)
# 1127846    -86.713  (36.259, -86.713)
# 1127847    -86.762  (36.189, -86.762)
# 1127848    -86.789  (36.174, -86.789)
# 1127850    -86.779  (36.152, -86.779)
# 1127851    -86.750   (36.205, -86.75)
# 1127852    -86.653  (36.258, -86.653)
# 1127853    -86.770   (36.157, -86.77)
# 1127854    -86.771  (36.167, -86.771)
#
# [973598 rows x 12 columns]

# %%
sns.heatmap(new_police_2016.isnull(), cbar=False)

# %%
new_police_2016.shape
# Out:
# (973598, 11)

# %%
new_police_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 973598 entries, 0 to 1127854
# Data columns (total 12 columns):
# Event Number               973598 non-null object
# Call Received              973598 non-null object
# Shift                      973598 non-null object
# Tencode                    973598 non-null object
# Tencode Description        973598 non-null object
# Disposition Code           973598 non-null int64
# Disposition Description    973598 non-null object
# Unit Dispatched            973598 non-null object
# Sector                     973598 non-null object
# Latitude                   973598 non-null float64
# Longitude                  973598 non-null float64
# Mapped Location            973598 non-null object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 96.6+ MB

# %%
new_police_2016["Tencode Description"].value_counts()
# Out:
# Traffic Violation                              258687
# Business Check                                 199648
# Want Officer for Investigation / Assistance    151452
# Community Policing Activity                     49418
# Administrative/Special Assignment               46920
# Vehicle Accident - Property Damage              35800
# Suspicious Person                               34210
# Disorderly Person                               31161
# Safety Hazard                                   30759
# Burglary - Residence                            21730
# Burglary - Non-Residence                        19410
# Theft                                           13088
# Investigate 911 Hang-Up Call                    12144
# Vehicle Accident - Personal Injury               9993
# Vehicle Blocking Right of Way                    9704
# Meal Break                                       7834
# Fight / Assault                                  6365
# Fixed Post                                       4494
# Shots Fired                                      4167
# Missing Person                                   3919
# Person with Weapon                               3077
# Dangerous / Injured Animal                       3031
# Transport Prisoner / Suspect                     2937
# Suicidal Person                                  2656
# Holdup / Robbery                                 2639
# Intoxicated Person                               2639
# Corpse / D. O. A.                                 911
# Person Indecently Exposed                         677
# Mentally ILL Person                               664
# Personal Relief                                   520
# Escort / Convoy                                   512
# Prowler                                           487
# Person Screaming                                  451
# Fire                                              406
# Shooting                                          237
# Hazardous Liquid / Gas Leak                       228
# Cutting / Stabbing                                145
# Kidnapping                                        145
# Bank Robbery                                       89
# Explosion                                          78
# Gang Activity                                      36
# Personnel in Serious Danger                        29
# Bomb Threat                                        24
# Drowning                                           21
# Barricaded Suspect                                 21
# Prisoner Escapee                                   20
# Occult Activity                                     7
# Riot / Disorderly Crowd                             6
# Train Derailment                                    1
# Aircraft Crash                                      1
# Name: Tencode Description, dtype: int64

# %%
plt.figure(figsize = (15, 10))
sns.countplot(y= 'Tencode Description', data =new_police_2016, order =new_police_2016['Tencode Description'].value_counts().iloc[:26].index)

# %%
not_real_crime=new_police_2016[
    (new_police_2016["Tencode Description"]=="Traffic Violation") |
    (new_police_2016["Tencode Description"]=="Business Check")|
    (new_police_2016["Tencode Description"]=="Want Officer for Investigation / Assistance")|
    (new_police_2016["Tencode Description"]=="Community Policing Activity")|
    (new_police_2016["Tencode Description"]=="Administrative/Special Assignment")|
    (new_police_2016["Tencode Description"]=="Vehicle Accident - Property Damage")|
    (new_police_2016["Tencode Description"]=="Vehicle Accident - Personal Injury")|
    (new_police_2016["Tencode Description"]=="Vehicle Blocking Right of Way")|
    (new_police_2016["Tencode Description"]=="Fixed Post")|
     (new_police_2016["Tencode Description"]=="Business Check")|
    (new_police_2016["Tencode Description"]=="Dangerous / Injured Animal")|
    (new_police_2016["Tencode Description"]=="Meal Break")]
not_real_crime["Tencode Description"].value_counts()
# Out:
# Traffic Violation                              258687
# Business Check                                 199648
# Want Officer for Investigation / Assistance    151452
# Community Policing Activity                     49418
# Administrative/Special Assignment               46920
# Vehicle Accident - Property Damage              35800
# Vehicle Accident - Personal Injury               9993
# Vehicle Blocking Right of Way                    9704
# Meal Break                                       7834
# Fixed Post                                       4494
# Dangerous / Injured Animal                       3031
# Name: Tencode Description, dtype: int64

# %%
real_crime=new_police_2016[
    (new_police_2016["Tencode Description"]=="Suspicious Person") |
    (new_police_2016["Tencode Description"]=="Safety Hazard")|
    (new_police_2016["Tencode Description"]=="Burglary - Residence")|
    (new_police_2016["Tencode Description"]=="Burglary - Non-Residence")|
    (new_police_2016["Tencode Description"]=="Investigate 911 Hang-Up Call")|
    (new_police_2016["Tencode Description"]=="Theft")|
    (new_police_2016["Tencode Description"]=="Fight / Assault")|
    (new_police_2016["Tencode Description"]=="Shots Fired")|
    (new_police_2016["Tencode Description"]=="Missing Person")|
    (new_police_2016["Tencode Description"]=="Person with Weapon")|
    (new_police_2016["Tencode Description"]=="Transport Prisoner / Suspect")|
    (new_police_2016["Tencode Description"]=="Intoxicated Person")|
    (new_police_2016["Tencode Description"]=="Suicidal Person")|
    (new_police_2016["Tencode Description"]=="Holdup / Robbery")|
    (new_police_2016["Tencode Description"]=="Corpse / D. O. A.")|
    (new_police_2016["Tencode Description"]=="Mentally ILL Person")|
    (new_police_2016["Tencode Description"]=="Personal Relief")|
    (new_police_2016["Tencode Description"]=="Escort / Convoy")|
    (new_police_2016["Tencode Description"]=="Prowler")|
    (new_police_2016["Tencode Description"]=="Person Screaming")|
    (new_police_2016["Tencode Description"]=="Fire")|
    (new_police_2016["Tencode Description"]=="Shooting")|
    (new_police_2016["Tencode Description"]=="Hazardous Liquid / Gas Leak")|
    (new_police_2016["Tencode Description"]=="Kidnapping")|
    (new_police_2016["Tencode Description"]=="Cutting / Stabbing")|
    (new_police_2016["Tencode Description"]=="Bank Robbery")|
    (new_police_2016["Tencode Description"]=="Explosion")|
    (new_police_2016["Tencode Description"]=="Gang Activity")|
    (new_police_2016["Tencode Description"]=="Bomb Threat")|
    (new_police_2016["Tencode Description"]=="Prisoner Escapee")|
    (new_police_2016["Tencode Description"]=="Drowning")|
    (new_police_2016["Tencode Description"]=="Barricaded Suspect")
]
real_crime["Tencode Description"].value_counts()
# Out:
# Suspicious Person               34210
# Safety Hazard                   30759
# Burglary - Residence            21730
# Burglary - Non-Residence        19410
# Theft                           13088
# Investigate 911 Hang-Up Call    12144
# Fight / Assault                  6365
# Shots Fired                      4167
# Missing Person                   3919
# Person with Weapon               3077
# Transport Prisoner / Suspect     2937
# Suicidal Person                  2656
# Holdup / Robbery                 2639
# Intoxicated Person               2639
# Corpse / D. O. A.                 911
# Mentally ILL Person               664
# Personal Relief                   520
# Escort / Convoy                   512
# Prowler                           487
# Person Screaming                  451
# Fire                              406
# Shooting                          237
# Hazardous Liquid / Gas Leak       228
# Kidnapping                        145
# Cutting / Stabbing                145
# Bank Robbery                       89
# Explosion                          78
# Gang Activity                      36
# Bomb Threat                        24
# Drowning                           21
# Barricaded Suspect                 21
# Prisoner Escapee                   20
# Name: Tencode Description, dtype: int64

# %%
#important_crime=pd.DataFrame(real_crime)

# %%
# Create a new columns for Year, Day and Month, Hour
time_crime_2016=pd.DataFrame(real_crime)
time_crime_2016["Month"] = time_crime_2016["Call Received"].str.rstrip('/').str.split('/').str[0]
time_crime_2016["Day"] = time_crime_2016["Call Received"].str.rstrip('/').str.split('/').str[1]
time_crime_2016["Year"] = time_crime_2016["Call Received"].str.slice(6,11)
time_crime_2016["Time"] = time_crime_2016["Call Received"].str.slice(11,24) 

#crime_data_All_DF["Hour"] = crime_data_All_DF["Time"].str.rstrip(':').str.split(':').str[0].astype(int) 
time_crime_2016.head()
# Out:
#       Event Number           Call Received Shift Tencode Tencode Description  \
# 7   PD201600000008  01/01/2016 12:02:00 AM     C      83         Shots Fired
# 13  PD201600000015  01/01/2016 12:03:00 AM     C      83         Shots Fired
# 14  PD201600000016  01/01/2016 12:03:00 AM     C      83         Shots Fired
# 16  PD201600000019  01/01/2016 12:05:00 AM     C      83         Shots Fired
# 17  PD201600000022  01/01/2016 12:05:00 AM     C      83         Shots Fired
#
#     Disposition Code Disposition Description Unit Dispatched Sector  Latitude  \
# 7                  5         GONE ON ARRIVAL            613C      N    36.179
# 13                10             NO RESPONSE            330C      S    36.072
# 14                11    DISREGARD / SIGNAL 9            711C      M    36.235
# 16                 5         GONE ON ARRIVAL            625C      N    36.238
# 17                 6     ASSISTED OTHER UNIT            2F21      E    36.180
#
#     Longitude    Mapped Location Month Day   Year         Time
# 7     -86.818  (36.179, -86.818)    01  01  2016   12:02:00 AM
# 13    -86.603  (36.072, -86.603)    01  01  2016   12:03:00 AM
# 14    -86.766  (36.235, -86.766)    01  01  2016   12:03:00 AM
# 16    -86.808  (36.238, -86.808)    01  01  2016   12:05:00 AM
# 17    -86.772   (36.18, -86.772)    01  01  2016   12:05:00 AM

# %%
def convert_to_24(time):
    if time[-2:] == "AM" and time[:2] == "12":
        return "00"+time[2:-2]
    elif time[-2:] == "AM":
        return time[:-2]
    elif time[-2:] == "PM" and time[:2] == "12":
        return time[:-2]
    else:
        return str(int(time[:2]) + 12) + time[2:8]

# %%
time_crime_2016['Time'] = time_crime_2016['Time'].apply(convert_to_24)

# %%
time_crime_2016["Hour"] = time_crime_2016["Time"].str.slice(0,2).astype(int)
time_crime_2016.tail()
# Out:
#            Event Number           Call Received Shift Tencode  \
# 1127837  PD201601315888  12/31/2016 10:45:00 PM     B      57
# 1127841  PD201601315892  12/31/2016 10:48:00 PM     B      83
# 1127842  PD201601315893  12/31/2016 10:49:00 PM     B      71
# 1127846  PD201601315897  12/31/2016 10:51:00 PM     B      57
# 1127852  PD201601315908  12/31/2016 10:56:00 PM     B      40
#
#               Tencode Description  Disposition Code   Disposition Description  \
# 1127837           Fight / Assault                 5           GONE ON ARRIVAL
# 1127841               Shots Fired                11      DISREGARD / SIGNAL 9
# 1127842  Burglary - Non-Residence                12  LOCATION/BUILDING SECURE
# 1127846           Fight / Assault                 6       ASSISTED OTHER UNIT
# 1127852         Suspicious Person                 5           GONE ON ARRIVAL
#
#         Unit Dispatched Sector  Latitude  Longitude    Mapped Location Month  \
# 1127837            810C     MT    36.149    -86.798  (36.149, -86.798)    12
# 1127841            621C      N    36.228    -86.796  (36.228, -86.796)    12
# 1127842            331C      S    36.056    -86.715  (36.056, -86.715)    12
# 1127846            711C      M    36.259    -86.713  (36.259, -86.713)    12
# 1127852            523C      H    36.258    -86.653  (36.258, -86.653)    12
#
#         Day   Year      Time  Hour
# 1127837  31  2016   22:45:00    22
# 1127841  31  2016   22:48:00    22
# 1127842  31  2016   22:49:00    22
# 1127846  31  2016   22:51:00    22
# 1127852  31  2016   22:56:00    22

# %%
#bins = [0, 7, 12, 18, 23]
#group_names = ['Early Morning', 'Morning', 'Afternoon', 'Evening', 'Night']
bins = [-1, 7, 12, 18, 23]
group_names = ['Early Morning', 'Morning', 'Afternoon', 'Evening']


time_crime_2016["Hour Bin"] = pd.cut(time_crime_2016["Hour"], bins, labels=group_names)
time_crime_2016.tail(2)
# Out:
#            Event Number           Call Received Shift Tencode  \
# 1127846  PD201601315897  12/31/2016 10:51:00 PM     B      57
# 1127852  PD201601315908  12/31/2016 10:56:00 PM     B      40
#
#         Tencode Description  Disposition Code Disposition Description  \
# 1127846     Fight / Assault                 6     ASSISTED OTHER UNIT
# 1127852   Suspicious Person                 5         GONE ON ARRIVAL
#
#         Unit Dispatched Sector  Latitude  Longitude    Mapped Location Month  \
# 1127846            711C      M    36.259    -86.713  (36.259, -86.713)    12
# 1127852            523C      H    36.258    -86.653  (36.258, -86.653)    12
#
#         Day   Year      Time  Hour Hour Bin
# 1127846  31  2016   22:51:00    22  Evening
# 1127852  31  2016   22:56:00    22  Evening

# %%
#Bar chart of tencode descriptions
fig, ax = plt.subplots()

time_crime_2016['Tencode Description'].value_counts().plot(ax=ax, kind='bar')

# %%
#Bar graph of months by number of calls
fig, ax = plt.subplots()
time_crime_2016['Month'].value_counts().plot(ax=ax, kind='bar')

# %%
#Bar graph of calls per Sector of the City
fig, ax = plt.subplots()
time_crime_2016['Sector'].value_counts().plot(ax=ax, kind='bar')

# %%
#Pie chart of Tencode descriptions
time_crime_2016['Tencode Description'].value_counts().plot(kind='pie')

# %%
#Bar chart of hour bins
fig, ax = plt.subplots()
time_crime_2016['Hour Bin'].value_counts().plot(ax=ax, kind='bar')

# %%
#Bar chart of calls byhour 
fig, ax = plt.subplots()
time_crime_2016['Hour'].value_counts().plot(ax=ax, kind='bar')

# %%
df_gb_2016 = pd.DataFrame(time_crime_2016.groupby(['Sector', 'Hour']).size())
df_gb_2016.reset_index(inplace=True)
df_gb_2016.rename(columns={0:"Tencode Description"}, inplace=True)
df_h = df_gb_2016.pivot("Sector", "Hour", "Tencode Description")
fig, ax = plt.subplots()
fig.set_size_inches(16, 4)
ax = sns.heatmap(df_h, ax=ax, cmap= sns.cm.rocket_r )
plt.title('Heat Map : Crime by District and Hour of day - 2016', fontsize=20, weight='bold')
plt.savefig ("heatmap_sector_2016.png")
plt.show()

# %%
df_gb_2016 = pd.DataFrame(time_crime_2016.groupby(['Tencode Description', 'Hour']).size())
df_gb_2016.reset_index(inplace=True)
df_gb_2016.rename(columns={0:"Tencode"}, inplace=True)
df_h = df_gb_2016.pivot("Tencode Description", "Hour", "Tencode")
fig, ax = plt.subplots()
fig.set_size_inches(16, 20)
ax = sns.heatmap(df_h, ax=ax, cmap= sns.cm.rocket_r )
plt.title('Heat Map : Crime by Tencode Description and Hour of day - 2016', fontsize=30, weight='bold')
plt.savefig ("heatmap_time_2016.png")
plt.show(5)

# %%
df_gb_2016 = pd.DataFrame(time_crime_2016.groupby(['Tencode Description', 'Month']).size())
df_gb_2016.reset_index(inplace=True)
df_gb_2016.rename(columns={0:"Tencode"}, inplace=True)
df_h = df_gb_2016.pivot("Tencode Description", "Month", "Tencode")
fig, ax = plt.subplots()
fig.set_size_inches(16, 20)
ax = sns.heatmap(df_h, ax=ax, cmap= sns.cm.rocket_r )
plt.title('Heat Map : Crime by Tencode Description and Month - 2016', fontsize=30, weight='bold')
plt.savefig ("heatmap_month_2016.png")
plt.show(5)

# %%
locations = real_crime.groupby('Tencode Description').first()

# %%
popup_text = """Tencode Description : {}<br
                Mapped Location : {}<br>"""

# %%
new_locations = locations.loc[:, ['Latitude', 'Longitude', 'Mapped Location']]
new_locations.head()

nashville_map = folium.Map(location=[36.168,-86.779],
                        zoom_start=15,
                        tiles="Stamen Terrain")
nashville_map

for i in range(len(new_locations)):
    lat = new_locations.iloc[i][0]
    long = new_locations.iloc[i][1]
    popup_text = """Tencode Description : {}<br
                Mapped Location : {}<br>"""
    popup_text = popup_text.format(new_locations.index[i],
                               new_locations.iloc[i][-1],
                               new_locations.iloc[i][-2]
                               )

    folium.CircleMarker(location = [lat, long], popup= popup_text, fill = True).add_to(nashville_map)

nashville_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
unique_locations = real_crime['Mapped Location'].value_counts()
unique_locations.head()
# Out:
# (36.161, -86.777)    572
# (36.131, -86.907)    407
# (36.176, -86.608)    364
# (36.162, -86.776)    358
# (36.154, -86.778)    347
# Name: Mapped Location, dtype: int64

# %%
unique_locations.index
# Out:
# Index(['(36.161, -86.777)', '(36.131, -86.907)', '(36.176, -86.608)',
#        '(36.162, -86.776)', '(36.154, -86.778)', '(36.077, -86.721)',
#        '(36.153, -86.809)', '(36.244, -86.762)', '(36.082, -86.726)',
#        '(36.166, -86.807)',
#        ...
#        '(36.063, -86.756)', '(36.126, -86.834)', '(36.065, -86.728)',
#        '(36.051, -86.935)', '(36.215, -86.897)', '(36.246, -86.674)',
#        '(36.104, -86.826)', '(36.024, -86.721)', '(36.295, -86.708)',
#        '(36.23, -86.733)'],
#       dtype='object', length=29721)

# %%
real_crime_index = pd.DataFrame({"Raw_String" : unique_locations.index, "ValueCount":unique_locations})
real_crime_index.index = range(len(unique_locations))
real_crime_index.head()
# Out:
#           Raw_String  ValueCount
# 0  (36.161, -86.777)         572
# 1  (36.131, -86.907)         407
# 2  (36.176, -86.608)         364
# 3  (36.162, -86.776)         358
# 4  (36.154, -86.778)         347

# %%
def Location_extractor(Raw_Str):
    preProcess = Raw_Str[1:-1].split(',')
    lat =  float(preProcess[0])
    long = float(preProcess[1])
    return (lat, long)

# %%
real_crime_index['LocationCoord'] = real_crime_index['Raw_String'].apply(Location_extractor)
real_crime_index['LocationCoord'].head()
# Out:
# 0    (36.161, -86.777)
# 1    (36.131, -86.907)
# 2    (36.176, -86.608)
# 3    (36.162, -86.776)
# 4    (36.154, -86.778)
# Name: LocationCoord, dtype: object

# %%
real_crime_index  = real_crime_index.drop(columns=['Raw_String'], axis = 1)
real_crime_index.head()
# Out:
#    ValueCount      LocationCoord
# 0         572  (36.161, -86.777)
# 1         407  (36.131, -86.907)
# 2         364  (36.176, -86.608)
# 3         358  (36.162, -86.776)
# 4         347  (36.154, -86.778)

# %%
#%%time

nashville_map_crime = folium.Map(location=[36.168, -86.779],
                        zoom_start=13,
                       tiles="Stamen Terrain")

for i in range(500):
    lat = real_crime_index['LocationCoord'].iloc[i][0]
    long = real_crime_index['LocationCoord'].iloc[i][1]
    radius = real_crime_index['ValueCount'].iloc[i] / 45
    
    if real_crime_index['ValueCount'].iloc[i] > 200:
        color = "#FF4500"
    else:
        color = "#008080"
    
    popup_text = """Latitude : {}<br>
                Longitude : {}<br>
                Criminal Incidents : {}<br>"""
    popup_text = popup_text.format(lat,
                               long,
                               real_crime_index['ValueCount'].iloc[i]
                               )
    folium.CircleMarker(location = [lat, long], popup= popup_text,radius = radius, color = color, fill = True).add_to(nashville_map_crime)
    
nashville_map_crime
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
