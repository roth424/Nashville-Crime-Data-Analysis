# %%
#import packages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sqlite3 as sql
import folium
import gmaps

# %matplotlib inline

# %%
#2.	Read in police call data for 2016 to a data frame called police_2013 and look at the first 5 rows. 
    #Look at the last five rows of police_2016.


police_2016 = pd.read_csv('Metro_Nashville_Davidson_County_Calls_For_Police_Service__2016_.csv')
police_2016
# Out:
#            Event Number           Call Received  Complaint Number Shift  \
# 0        PD201600000001  01/01/2016 12:00:00 AM       20160000002     C
# 1        PD201600000002  01/01/2016 12:00:00 AM       20160000003     C
# 2        PD201600000003  01/01/2016 12:00:00 AM       20160000017     C
# 3        PD201600000004  01/01/2016 12:00:00 AM                 0     C
# 4        PD201600000005  01/01/2016 12:00:00 AM       20160000005     C
# 5        PD201600000006  01/01/2016 12:00:00 AM       20160000006     C
# 6        PD201600000007  01/01/2016 12:00:00 AM                 0     C
# 7        PD201600000008  01/01/2016 12:02:00 AM       20160000011     C
# 8        PD201600000009  01/01/2016 12:02:00 AM       20160000008     C
# 9        PD201600000010  01/01/2016 12:02:00 AM                 0     C
# 10       PD201600000011  01/01/2016 12:02:00 AM                 0     C
# 11       PD201600000012  01/01/2016 12:02:00 AM       20160000010     C
# 12       PD201600000013  01/01/2016 12:02:00 AM       20160000009     C
# 13       PD201600000015  01/01/2016 12:03:00 AM       20160000014     C
# 14       PD201600000016  01/01/2016 12:03:00 AM       20160000013     C
# 15       PD201600000018  01/01/2016 12:05:00 AM                 0     C
# 16       PD201600000019  01/01/2016 12:05:00 AM       20160000070     C
# 17       PD201600000022  01/01/2016 12:05:00 AM       20160000015     C
# 18       PD201600000023  01/01/2016 12:05:00 AM       20160000023     C
# 19       PD201600000024  01/01/2016 12:06:00 AM       20160000016     C
# 20       PD201600000025  01/01/2016 12:06:00 AM                 0     C
# 21       PD201600000026  01/01/2016 12:07:00 AM       20160000022     C
# 22       PD201600000027  01/01/2016 12:07:00 AM       20160000019     C
# 23       PD201600000028  01/01/2016 12:07:00 AM       20160000020     C
# 24       PD201600000029  01/01/2016 12:07:00 AM       20160000057     C
# 25       PD201600000030  01/01/2016 12:08:00 AM       20160000055     C
# 26       PD201600000031  01/01/2016 12:08:00 AM                 0     C
# 27       PD201600000033  01/01/2016 12:08:00 AM       20160000041     C
# 28       PD201600000207  01/01/2016 01:18:00 AM       20160000703     C
# 29       PD201600000034  01/01/2016 12:09:00 AM       20160000088     C
# ...                 ...                     ...               ...   ...
# 1127929  PD201601316017  12/31/2016 11:41:00 PM       20170000141   NaN
# 1127930  PD201601316018  12/31/2016 11:41:00 PM       20161153506   NaN
# 1127931  PD201601316019  12/31/2016 11:41:00 PM       20161153521   NaN
# 1127932  PD201601316020  12/31/2016 11:41:00 PM       20161153507   NaN
# 1127933  PD201601316021  12/31/2016 11:41:00 PM                 0   NaN
# 1127934  PD201601316022  12/31/2016 11:42:00 PM       20161153508   NaN
# 1127935  PD201601316024  12/31/2016 11:44:00 PM       20161153514   NaN
# 1127936  PD201601316025  12/31/2016 11:45:00 PM       20161153517   NaN
# 1127937  PD201601316028  12/31/2016 11:47:00 PM       20161153519   NaN
# 1127938  PD201601316029  12/31/2016 11:49:00 PM       20161153520   NaN
# 1127939  PD201601316030  12/31/2016 11:50:00 PM                 0   NaN
# 1127940  PD201601316031  12/31/2016 11:51:00 PM       20161153523   NaN
# 1127941  PD201601316032  12/31/2016 11:51:00 PM                 0   NaN
# 1127942  PD201601316033  12/31/2016 11:51:00 PM       20161153524   NaN
# 1127943  PD201601316034  12/31/2016 11:51:00 PM       20170000372   NaN
# 1127944  PD201601316035  12/31/2016 11:51:00 PM       20161153527   NaN
# 1127945  PD201601316037  12/31/2016 11:52:00 PM       20170000046   NaN
# 1127946  PD201601316039  12/31/2016 11:52:00 PM       20170000147   NaN
# 1127947  PD201601316040  12/31/2016 11:52:00 PM       20170000156   NaN
# 1127948  PD201601316041  12/31/2016 11:53:00 PM       20161153526   NaN
# 1127949  PD201601316043  12/31/2016 11:53:00 PM       20161153530   NaN
# 1127950  PD201601316044  12/31/2016 11:53:00 PM       20161153528   NaN
# 1127951  PD201601316045  12/31/2016 11:54:00 PM       20170000145   NaN
# 1127952  PD201601316046  12/31/2016 11:57:00 PM       20161153531   NaN
# 1127953  PD201601316047  12/31/2016 11:57:00 PM       20161153534   NaN
# 1127954  PD201601316048  12/31/2016 11:57:00 PM       20161153532   NaN
# 1127955  PD201601316049  12/31/2016 11:58:00 PM                 0   NaN
# 1127956  PD201601316051  12/31/2016 11:58:00 PM       20161153535   NaN
# 1127957  PD201601316052  12/31/2016 11:59:00 PM       20161153536   NaN
# 1127958  PD201601316053  12/31/2016 11:59:00 PM       20170000088   NaN
#
#         Tencode                          Tencode Description Tencode Suffix  \
# 0            96                               Business Check            NaN
# 1            96                               Business Check            NaN
# 2            45           Vehicle Accident - Property Damage              P
# 3            83                                  Shots Fired              P
# 4            96                               Business Check            NaN
# 5            46           Vehicle Accident - Personal Injury              P
# 6            83                                  Shots Fired              P
# 7            83                                  Shots Fired              P
# 8            83                                  Shots Fired              P
# 9            83                                  Shots Fired              P
# 10           42                           Intoxicated Person              P
# 11           43  Want Officer for Investigation / Assistance              P
# 12           93                            Traffic Violation            NaN
# 13           83                                  Shots Fired              P
# 14           83                                  Shots Fired              P
# 15           83                                  Shots Fired              P
# 16           83                                  Shots Fired              P
# 17           83                                  Shots Fired              P
# 18           83                                  Shots Fired              P
# 19           42                           Intoxicated Person              P
# 20           83                                  Shots Fired              P
# 21           71                     Burglary - Non-Residence              A
# 22           43  Want Officer for Investigation / Assistance              P
# 23           83                                  Shots Fired              P
# 24           83                                  Shots Fired              P
# 25           83                                  Shots Fired              P
# 26           83                                  Shots Fired              P
# 27           83                                  Shots Fired              P
# 28           70                         Burglary - Residence              R
# 29           83                                  Shots Fired              P
# ...         ...                                          ...            ...
# 1127929      40                            Suspicious Person             PV
# 1127930      46           Vehicle Accident - Personal Injury              P
# 1127931      83                                  Shots Fired              P
# 1127932      93                            Traffic Violation            NaN
# 1127933      45           Vehicle Accident - Property Damage              P
# 1127934      96                               Business Check            NaN
# 1127935      93                            Traffic Violation            NaN
# 1127936      83                                  Shots Fired              P
# 1127937      57                              Fight / Assault              P
# 1127938      93                            Traffic Violation            NaN
# 1127939      70                         Burglary - Residence              A
# 1127940      93                            Traffic Violation            NaN
# 1127941      83                                  Shots Fired              P
# 1127942      93                            Traffic Violation            NaN
# 1127943      49                Vehicle Blocking Right of Way              P
# 1127944      49                Vehicle Blocking Right of Way              P
# 1127945      71                     Burglary - Non-Residence              A
# 1127946      71                     Burglary - Non-Residence              A
# 1127947      57                              Fight / Assault              P
# 1127948      96                               Business Check            NaN
# 1127949      44                            Disorderly Person              P
# 1127950      54                           Person with Weapon              P
# 1127951      45           Vehicle Accident - Property Damage              P
# 1127952      96                               Business Check            NaN
# 1127953      83                                  Shots Fired              P
# 1127954      43  Want Officer for Investigation / Assistance              P
# 1127955      43  Want Officer for Investigation / Assistance             PM
# 1127956      46           Vehicle Accident - Personal Injury              P
# 1127957      43  Want Officer for Investigation / Assistance              P
# 1127958      45           Vehicle Accident - Property Damage              P
#
#                       Tencode Suffix Description  Disposition Code  \
# 0                                            NaN                12
# 1                                            NaN                12
# 2                                       PROGRESS                 1
# 3                                       PROGRESS                11
# 4                                            NaN                12
# 5                                       PROGRESS                11
# 6                                       PROGRESS                11
# 7                                       PROGRESS                 5
# 8                                       PROGRESS                11
# 9                                       PROGRESS                11
# 10                                      PROGRESS                11
# 11                                      PROGRESS                 6
# 12                                           NaN                 9
# 13                                      PROGRESS                10
# 14                                      PROGRESS                11
# 15                                      PROGRESS                11
# 16                                      PROGRESS                 5
# 17                                      PROGRESS                 6
# 18                                      PROGRESS                 6
# 19                                      PROGRESS                 2
# 20                                      PROGRESS                11
# 21                                         ALARM                 6
# 22                                      PROGRESS                 2
# 23                                      PROGRESS                11
# 24                                      PROGRESS                 5
# 25                                      PROGRESS                11
# 26                                      PROGRESS                11
# 27                                      PROGRESS                10
# 28                                        REPORT                 1
# 29                                      PROGRESS                 5
# ...                                          ...               ...
# 1127929  IN PROGRESS SITUATION INVOLVING VEHICLE                 4
# 1127930                                 PROGRESS                 6
# 1127931                                 PROGRESS                11
# 1127932                                      NaN                 9
# 1127933                                 PROGRESS                11
# 1127934                                      NaN                 0
# 1127935                                      NaN                 6
# 1127936                                 PROGRESS                 5
# 1127937                                 PROGRESS                 6
# 1127938                                      NaN                 9
# 1127939                                    ALARM                11
# 1127940                                      NaN                 9
# 1127941                                 PROGRESS                 0
# 1127942                                      NaN                 0
# 1127943                                 PROGRESS                 4
# 1127944                                 PROGRESS                 4
# 1127945                                    ALARM                12
# 1127946                                    ALARM                 4
# 1127947                                 PROGRESS                 4
# 1127948                                      NaN                 0
# 1127949                                 PROGRESS                 2
# 1127950                                 PROGRESS                 6
# 1127951                                 PROGRESS                 1
# 1127952                                      NaN                12
# 1127953                                 PROGRESS                 0
# 1127954                                 PROGRESS                11
# 1127955       REQUEST MNPD WITH MEDICAL RESPONSE                11
# 1127956                                 PROGRESS                 1
# 1127957                                 PROGRESS                 4
# 1127958                                 PROGRESS                 5
#
#                Disposition Description   Block  \
# 0             LOCATION/BUILDING SECURE   300.0
# 1             LOCATION/BUILDING SECURE   500.0
# 2                M.P.D. REPORT COMPLED     0.0
# 3                 DISREGARD / SIGNAL 9   500.0
# 4             LOCATION/BUILDING SECURE  1100.0
# 5                 DISREGARD / SIGNAL 9     0.0
# 6                 DISREGARD / SIGNAL 9   600.0
# 7                      GONE ON ARRIVAL  2500.0
# 8                 DISREGARD / SIGNAL 9     0.0
# 9                 DISREGARD / SIGNAL 9  1600.0
# 10                DISREGARD / SIGNAL 9     0.0
# 11                 ASSISTED OTHER UNIT   500.0
# 12                      SUBJECT WARNED     0.0
# 13                         NO RESPONSE  3100.0
# 14                DISREGARD / SIGNAL 9  3300.0
# 15                DISREGARD / SIGNAL 9     0.0
# 16                     GONE ON ARRIVAL  3400.0
# 17                 ASSISTED OTHER UNIT     0.0
# 18                 ASSISTED OTHER UNIT  1400.0
# 19       ARREST, CUSTODIAL OR CITATION     0.0
# 20                DISREGARD / SIGNAL 9  2100.0
# 21                 ASSISTED OTHER UNIT     NaN
# 22       ARREST, CUSTODIAL OR CITATION   600.0
# 23                DISREGARD / SIGNAL 9   600.0
# 24                     GONE ON ARRIVAL   500.0
# 25                DISREGARD / SIGNAL 9  3100.0
# 26                DISREGARD / SIGNAL 9  1500.0
# 27                         NO RESPONSE  1400.0
# 28               M.P.D. REPORT COMPLED     NaN
# 29                     GONE ON ARRIVAL   500.0
# ...                                ...     ...
# 1127929               ASSISTED CITIZEN  1000.0
# 1127930            ASSISTED OTHER UNIT  3700.0
# 1127931           DISREGARD / SIGNAL 9   100.0
# 1127932                 SUBJECT WARNED     0.0
# 1127933           DISREGARD / SIGNAL 9  3500.0
# 1127934                            NaN  7300.0
# 1127935            ASSISTED OTHER UNIT     0.0
# 1127936                GONE ON ARRIVAL     0.0
# 1127937            ASSISTED OTHER UNIT     0.0
# 1127938                 SUBJECT WARNED     0.0
# 1127939           DISREGARD / SIGNAL 9  1000.0
# 1127940                 SUBJECT WARNED  2500.0
# 1127941                            NaN     0.0
# 1127942                            NaN  1000.0
# 1127943               ASSISTED CITIZEN  3400.0
# 1127944               ASSISTED CITIZEN     0.0
# 1127945       LOCATION/BUILDING SECURE  2000.0
# 1127946               ASSISTED CITIZEN  1300.0
# 1127947               ASSISTED CITIZEN  1100.0
# 1127948                            NaN  7300.0
# 1127949  ARREST, CUSTODIAL OR CITATION   100.0
# 1127950            ASSISTED OTHER UNIT     NaN
# 1127951          M.P.D. REPORT COMPLED  3400.0
# 1127952       LOCATION/BUILDING SECURE     0.0
# 1127953                            NaN  2000.0
# 1127954           DISREGARD / SIGNAL 9     0.0
# 1127955           DISREGARD / SIGNAL 9  2100.0
# 1127956          M.P.D. REPORT COMPLED     0.0
# 1127957               ASSISTED CITIZEN     0.0
# 1127958                GONE ON ARRIVAL     0.0
#
#                             Street Name Unit Dispatched Sector  Zone  \
# 0                            HERRON DR             311C      S  11.0
# 1                              MAIN ST             213C      E  11.0
# 2           EDMONDSON PKE & MCMURRAY DR            835C     MT  33.0
# 3                             S 5TH ST              NaN      E  11.0
# 4                              BELL RD             333C      S  25.0
# 5         MT VIEW RD & MURFREESBORO PKE            333C      S  33.0
# 6                             S 6TH ST              NaN      E  11.0
# 7                             SANTI AV             613C      N  13.0
# 8                          HERMITAGE AV            511C    NaN   NaN
# 9                             CAHAL AV              NaN      E  17.0
# 10                  4TH AV N & BROADWAY             NaN      C  21.0
# 11                           SUMMER PL             213C      E  11.0
# 12       OLD HICKORY BLVD W & NESBITT D            721C      M  25.0
# 13                     COUNTRY LAWN DR             330C      S  35.0
# 14                        CREEKWOOD DR             711C      M  21.0
# 15              STAINBACK AV & MARIE ST             NaN      E  21.0
# 16                          TISDALL DR             625C      N  27.0
# 17              TREUTLAND AV & N 2ND ST            2F21      E  21.0
# 18                            JONES AV             221C      E  21.0
# 19               3RD AV N & COMMERCE ST           SQUAD      C  21.0
# 20                        ROCK CITY ST              NaN      E  17.0
# 21                         VAILVIEW DR             727C    NaN   NaN
# 22                        LAFAYETTE ST             423C      C  23.0
# 23                           41ST AV N             110C      W  11.0
# 24                     MILL STATION DR             627C      N  21.0
# 25                        GWYNNWOOD DR             627C      N  21.0
# 26                           PORTER RD              NaN      E  15.0
# 27                           LITTON AV             217C      E  17.0
# 28                      MONTE LEONE CT             321A    NaN   NaN
# 29               MARGARET ROBERTSON DR             523C      H  23.0
# ...                                 ...             ...    ...   ...
# 1127929                 RIVERGATE PKWY             725C      M  27.0
# 1127930                WILLOW CREEK RD             727C      M  21.0
# 1127931                      BRENDA LN             325C      S  21.0
# 1127932  BRILEY PKWY & ARBOR CREEK BLVD            5151      H  31.0
# 1127933               BRICK CHURCH PKE              NaN      M  21.0
# 1127934                  CHARLOTTE PKE             1F64      W  23.0
# 1127935               S 7TH ST & DEW ST            2F13      E  11.0
# 1127936         VERITAS ST & SAINDON ST            831C     MT  31.0
# 1127937                        5TH AV S            5D57    NaN   NaN
# 1127938       GALLATIN PKE & IVERSON AV            222C      E  17.0
# 1127939                       2ND AV S              NaN      S  11.0
# 1127940                  DICKERSON PKE             223C      E  23.0
# 1127941  GARFIELD ST & ROSA L PARKS BLV            617C      N  17.0
# 1127942                    PATRICIA DR             532C      H  31.0
# 1127943                    LEBANON PKE             520C      H  21.0
# 1127944           SHELBY AV & S 16TH ST            213C      E  13.0
# 1127945                 ED TEMPLE BLVD             611C      N  11.0
# 1127946               BRICK CHURCH PKE             6F70      N  21.0
# 1127947                    TUCKAHOE DR             723C      M  25.0
# 1127948                  CHARLOTTE PKE             1F62      W  23.0
# 1127949                       BROADWAY             SQA2      C  21.0
# 1127950                       9TH AV S             215C    NaN   NaN
# 1127951                    LEBANON PKE             521C      H  21.0
# 1127952        21ST AV N & MEHARRY BLVD            6F76      N  15.0
# 1127953                 STRAIGHTWAY AV             210C      E  15.0
# 1127954             5TH AV S & BROADWAY            ST12      C  21.0
# 1127955                      12TH AV N              NaN      N  11.0
# 1127956         HAYWOOD LN & APACHE TRL            325C      S  21.0
# 1127957  DR D B TODD JR BLVD & ALBION S            6F70      N  15.0
# 1127958        I440 E & NOLENSVILLE PKE            825C     MT  25.0
#
#          Reporting Area (RPA)  Latitude  Longitude    Mapped Location
# 0                      8125.0    36.133    -86.752  (36.133, -86.752)
# 1                      1113.0    36.173    -86.764  (36.173, -86.764)
# 2                      8657.0    36.055    -86.743  (36.055, -86.743)
# 3                      1011.0    36.167    -86.762  (36.167, -86.762)
# 4                      8721.0    36.046    -86.666  (36.046, -86.666)
# 5                      8865.0    36.054    -86.619  (36.054, -86.619)
# 6                      1021.0    36.166    -86.759  (36.166, -86.759)
# 7                      4463.0    36.179    -86.818  (36.179, -86.818)
# 8                         NaN       NaN        NaN                NaN
# 9                      1431.0    36.196    -86.734  (36.196, -86.734)
# 10                     4107.0    36.161    -86.777  (36.161, -86.777)
# 11                     1013.0    36.166    -86.760   (36.166, -86.76)
# 12                     2145.0    36.267    -86.746  (36.267, -86.746)
# 13                     8975.0    36.072    -86.603  (36.072, -86.603)
# 14                     2005.0    36.235    -86.766  (36.235, -86.766)
# 15                     1897.0    36.197    -86.764  (36.197, -86.764)
# 16                     3223.0    36.238    -86.808  (36.238, -86.808)
# 17                     1967.0    36.180    -86.772   (36.18, -86.772)
# 18                     1873.0    36.197    -86.758  (36.197, -86.758)
# 19                        0.0    36.163    -86.777  (36.163, -86.777)
# 20                     1405.0    36.199    -86.728  (36.199, -86.728)
# 21                        NaN       NaN        NaN                NaN
# 22                     4025.0    36.154    -86.778  (36.154, -86.778)
# 23                     4533.0    36.156    -86.836  (36.156, -86.836)
# 24                     3023.0    36.228    -86.800    (36.228, -86.8)
# 25                     3029.0    36.234    -86.792  (36.234, -86.792)
# 26                     1335.0    36.193    -86.728  (36.193, -86.728)
# 27                     1413.0    36.202    -86.731  (36.202, -86.731)
# 28                        NaN       NaN        NaN                NaN
# 29                     9557.0    36.178    -86.598  (36.178, -86.598)
# ...                       ...       ...        ...                ...
# 1127929                1751.0    36.301    -86.699  (36.301, -86.699)
# 1127930                2045.0    36.257    -86.776  (36.257, -86.776)
# 1127931                8713.0    36.061    -86.692  (36.061, -86.692)
# 1127932               88943.0    36.136    -86.699  (36.136, -86.699)
# 1127933                2037.0    36.259    -86.777  (36.259, -86.777)
# 1127934                4701.0    36.117    -86.923  (36.117, -86.923)
# 1127935                1025.0    36.166    -86.756  (36.166, -86.756)
# 1127936                8513.0    36.098    -86.743  (36.098, -86.743)
# 1127937                   NaN       NaN        NaN                NaN
# 1127938                   0.0    36.208    -86.735  (36.208, -86.735)
# 1127939                8151.0    36.149    -86.767  (36.149, -86.767)
# 1127940                1891.0    36.212    -86.765  (36.212, -86.765)
# 1127941                4349.0    36.181    -86.796  (36.181, -86.796)
# 1127942                8817.0    36.129    -86.707  (36.129, -86.707)
# 1127943                9531.0    36.189    -86.628  (36.189, -86.628)
# 1127944                1223.0    36.170    -86.743   (36.17, -86.743)
# 1127945                4423.0    36.186    -86.823  (36.186, -86.823)
# 1127946                3007.0    36.203    -86.781  (36.203, -86.781)
# 1127947                2021.0    36.261    -86.759  (36.261, -86.759)
# 1127948                4701.0    36.117    -86.923  (36.117, -86.923)
# 1127949                4095.0    36.162    -86.774  (36.162, -86.774)
# 1127950                   NaN       NaN        NaN                NaN
# 1127951                9601.0    36.192    -86.625  (36.192, -86.625)
# 1127952                5351.0    36.168    -86.809  (36.168, -86.809)
# 1127953                1347.0    36.192    -86.730   (36.192, -86.73)
# 1127954                4109.0    36.160    -86.778   (36.16, -86.778)
# 1127955                4491.0    36.186    -86.808  (36.186, -86.808)
# 1127956                8707.0    36.070    -86.694   (36.07, -86.694)
# 1127957                5409.0    36.166    -86.805  (36.166, -86.805)
# 1127958                8321.0    36.123    -86.751  (36.123, -86.751)
#
# [1127959 rows x 19 columns]

# %%
#Checking if data contains Null Values or not

sns.heatmap(police_2016.isnull(), cbar=False)

# %%
#Disposition Description and its semantics

plt.figure(figsize = (15, 10))
sns.countplot(y= 'Disposition Description', data = police_2016, order = police_2016['Disposition Description'].value_counts().iloc[:9].index)

# %%
police_2016.fillna(0, inplace=True)

# %%
police_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1127959 entries, 0 to 1127958
# Data columns (total 19 columns):
# Event Number                  1127959 non-null object
# Call Received                 1127959 non-null object
# Complaint Number              1127959 non-null int64
# Shift                         1127959 non-null object
# Tencode                       1127959 non-null object
# Tencode Description           1127959 non-null object
# Tencode Suffix                1127959 non-null object
# Tencode Suffix Description    1127959 non-null object
# Disposition Code              1127959 non-null int64
# Disposition Description       1127959 non-null object
# Block                         1127959 non-null float64
# Street Name                   1127959 non-null object
# Unit Dispatched               1127959 non-null object
# Sector                        1127959 non-null object
# Zone                          1127959 non-null float64
# Reporting Area (RPA)          1127959 non-null float64
# Latitude                      1127959 non-null float64
# Longitude                     1127959 non-null float64
# Mapped Location               1127959 non-null object
# dtypes: float64(5), int64(2), object(12)
# memory usage: 163.5+ MB

# %%
import gmaps
from config import gkey

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)



# Store latitude and longitude in locations
locations = police_2016[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
#rating = police_2016["Airport Rating"].astype(float)



rating = police_2016['Mapped Location'].value_counts().iloc[:19].index.astype(float)

fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig

#nashville_map_crime = folium.Map(location=[36.133, -86.751],
#                        zoom_start=13,
#                        tiles="CartoDB dark_matter")

#for i in range(500):
#    lat = CR_index['LocationCoord'].iloc[i][0]
#    long = CR_index['LocationCoord'].iloc[i][1]
#    radius = CR_index['ValueCount'].iloc[i] / 45
    
#    if CR_index['ValueCount'].iloc[i] > 1000:
#       color = "#FF4500"
#    else:
#        color = "#008080"
    
#    popup_text = """Latitude : {}<br>
#                Longitude : {}<br>
#                Criminal Incidents : {}<br>"""
#    popup_text = popup_text.format(lat,
#                              long,
#                               CR_index['ValueCount'].iloc[i]
#                               )
#    folium.CircleMarker(location = [lat, long], popup= popup_text,radius = radius, color = color, fill = True).add_to(chicago_map_crime)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-9863b75623cc> in <module>
#      25 heat_layer = gmaps.heatmap_layer(locations, weights=rating,
#      26                                  dissipating=False, max_intensity=10,
# ---> 27                                  point_radius=1)
#      28
#      29 fig.add_layer(heat_layer)
#
# /anaconda3/lib/python3.7/site-packages/gmaps/heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     264     widget_args, is_weighted = _heatmap_options(
#     265         locations, weights, max_intensity, dissipating, point_radius,
# --> 266         opacity, gradient
#     267     )
#     268     if is_weighted:
#
# /anaconda3/lib/python3.7/site-packages/gmaps/heatmap.py in _heatmap_options(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     207         if len(weights) != len(locations):
#     208             raise ValueError(
# --> 209                 'weights must be of the same length as locations or None')
#     210         is_weighted = True
#     211         widget_args = {
#
# ValueError: weights must be of the same length as locations or None

# %%
#3.	How many rows and columns does police_2016 contain?

police_2016.shape
# Out:
# (1048575, 13)

# %%
#4.	Keep just these 12 columns: 

keep_cols = ['Event Number', 'Call Received', 'Shift', 'Tencode', 'Tencode Description', 'Disposition Code', 'Disposition Description', 'Sector', 'Zone', 'Unit Dispatched', 'Latitude', 'Longitude']

police_2016_subset = police_2016[keep_cols]

police_2016_subset.columns
# Out:
# Index(['Event Number', 'Call Received', 'Shift', 'Tencode',
#        'Tencode Description', 'Disposition Code', 'Disposition Description',
#        'Sector', 'Zone', 'Unit Dispatched', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
police_2016.columns
# Out:
# Index(['Event Number', 'Call Received', 'Complaint Number', 'Shift', 'Tencode',
#        'Tencode Description', 'Tencode Suffix', 'Tencode Suffix Description',
#        'Disposition Code', 'Disposition Description', 'Block', 'Street Name',
#        'Unit Dispatched', 'Sector', 'Zone', 'Reporting Area (RPA)', 'Latitude',
#        'Longitude', 'Mapped Location'],
#       dtype='object')

# %%
#5.	Rename the columns above:

police_2016_subset = police_2016_subset.rename(columns = {'Event Number' : 'id' , 'Call Received' : 'call_time' , 'Shift' : 'shift' , 'Unit Dispatched': 'unit','Tencode' : 'tencode' , 'Tencode Description' : 'tencode_desc' , 'Disposition Code' : 'disposition' , 'Disposition Description' : 'disposition_desc', 'Sector' : 'sector' , 'Zone' : 'zone' , 'Latitude' : 'lat' , 'Longitude' : 'lng'})

police_2016_subset.columns
# Out:
# Index(['id', 'call_time', 'shift', 'tencode', 'tencode_desc', 'disposition',
#        'disposition_desc', 'sector', 'zone', 'unit', 'lat', 'lng'],
#       dtype='object')

# %%
#6.	Which unit answered the most calls in 2016? How many calls did they answer?

type_counts = police_2016_subset.unit.value_counts()
type_counts = type_counts.to_frame()
type_counts = type_counts.reset_index()
type_counts.iloc[0]
#most_calls = type_counts.loc[type_counts['unit'].idxmax()]
#df.loc[df['Score'].idxmax()]
#most_calls
# Out:
# index    125C
# unit     5388
# Name: 0, dtype: object

# %%
#7.	How many units answered more than 1000 calls in 2016?


GT1000 = type_counts.loc[type_counts['unit'] > 1000]
#df.loc[df['column_name'] == some_value]
GT1000.describe()

#sum(police_2016.units.value_counts()>1000)
# Out:
#               unit
# count   374.000000
# mean   2332.259358
# std     874.110201
# min    1001.000000
# 25%    1568.250000
# 50%    2253.000000
# 75%    2980.750000
# max    5388.000000

# %%
#8.	What tencode description is associated with the greatest number of calls in 2013?

tendesc = police_2016_subset.tencode_desc.value_counts()
tendesc = tendesc.to_frame()
tendesc = tendesc.reset_index()
tendesc = tendesc.rename(columns = {'index' : 'crime' , 'tencode_desc' : 'count'})
tendesc
#tendesc.iloc[0]
# Out:
#                                           crime   count
# 0                             Traffic Violation  282594
# 1                                Business Check  209057
# 2   Want Officer for Investigation / Assistance  176549
# 3             Administrative/Special Assignment   53501
# 4                   Community Policing Activity   51475
# 5            Vehicle Accident - Property Damage   42396
# 6                             Disorderly Person   39457
# 7                             Suspicious Person   37958
# 8                                 Safety Hazard   37327
# 9                                         Theft   34156
# 10                         Burglary - Residence   30481
# 11                     Burglary - Non-Residence   24742
# 12                 Investigate 911 Hang-Up Call   23104
# 13           Vehicle Accident - Personal Injury   11575
# 14                Vehicle Blocking Right of Way   10509
# 15                              Fight / Assault    9662
# 16                                   Meal Break    8073
# 17                                  Shots Fired    6135
# 18                                   Fixed Post    4642
# 19                               Missing Person    4413
# 20                             Holdup / Robbery    4411
# 21                           Person with Weapon    4352
# 22                   Dangerous / Injured Animal    4291
# 23                 Transport Prisoner / Suspect    3392
# 24                              Suicidal Person    3240
# 25                           Intoxicated Person    2996
# 26                            Corpse / D. O. A.    1230
# 27                    Person Indecently Exposed     804
# 28                          Mentally ILL Person     798
# 29                                      Prowler     665
# 30                                     Shooting     587
# 31                              Personal Relief     561
# 32                             Person Screaming     559
# 33                              Escort / Convoy     530
# 34                                         Fire     499
# 35                  Hazardous Liquid / Gas Leak     331
# 36                           Cutting / Stabbing     252
# 37                                   Kidnapping     196
# 38                                 Bank Robbery     106
# 39                                    Explosion      91
# 40                                Gang Activity      69
# 41                                  Bomb Threat      59
# 42                  Personnel in Serious Danger      38
# 43                                     Drowning      31
# 44                           Barricaded Suspect      23
# 45                             Prisoner Escapee      23
# 46                              Occult Activity       9
# 47                      Riot / Disorderly Crowd       7
# 48                             Train Derailment       1
# 49                                    Blood Run       1
# 50                               Aircraft Crash       1

# %%
tendesc.head()
# Out:
#                                          crime   count
# 0                            Traffic Violation  282594
# 1                               Business Check  209057
# 2  Want Officer for Investigation / Assistance  176549
# 3            Administrative/Special Assignment   53501
# 4                  Community Policing Activity   51475

# %%
tendesc10 = tendesc.iloc[0:10]
tendesc10
# Out:
#                                          crime   count
# 0                            Traffic Violation  282594
# 1                               Business Check  209057
# 2  Want Officer for Investigation / Assistance  176549
# 3            Administrative/Special Assignment   53501
# 4                  Community Policing Activity   51475
# 5           Vehicle Accident - Property Damage   42396
# 6                            Disorderly Person   39457
# 7                            Suspicious Person   37958
# 8                                Safety Hazard   37327
# 9                                        Theft   34156

# %%
#10.	Make a horizontal barplot of the crime counts.

#?plt.barh

plt.barh('crime', 'count', data=tendesc10, color = 'green', edgecolor = 'black');

#plt.barh('type', 'count', data=type_counts, color = 'green', edgecolor = 'black');

# %%
    #2.	Read in police call data for 2017 to a data frame called police_2017 and look at the first 5 rows. 
    #Look at the last five rows of police_2017.

police_2017 = pd.read_csv('Metro_Nashville_Davidson_County_Calls_For_Police_Service__2017_.csv')
police_2017.head()
police_2017.tail()
# Out:
#            Event Number           Call Received  Complaint Number Shift  \
# 1105378  PD201701313668  12/31/2017 11:56:00 PM       20171140163   NaN
# 1105379  PD201701313669  12/31/2017 11:57:00 PM       20180000007   NaN
# 1105380  PD201701313670  12/31/2017 11:58:00 PM       20180000005   NaN
# 1105381  PD201701313671  12/31/2017 11:58:00 PM       20171140167   NaN
# 1105382  PD201701313673  12/31/2017 11:59:00 PM       20180000008   NaN
#
#         Tencode Tencode Description Tencode Suffix  \
# 1105378      44   Disorderly Person              P
# 1105379      57     Fight / Assault              P
# 1105380      57     Fight / Assault              P
# 1105381      40   Suspicious Person             PV
# 1105382      83         Shots Fired              P
#
#                       Tencode Suffix Description  Disposition Code  \
# 1105378                                 PROGRESS                 4
# 1105379                                 PROGRESS                 4
# 1105380                                 PROGRESS                10
# 1105381  IN PROGRESS SITUATION INVOLVING VEHICLE                 4
# 1105382                                 PROGRESS                13
#
#         Disposition Description   Block        Street Name Unit Dispatched  \
# 1105378        ASSISTED CITIZEN     0.0  SHELBY AV & I24 E            UTV2
# 1105379        ASSISTED CITIZEN   400.0          BROADWAY            SQUAD
# 1105380             NO RESPONSE  1900.0       DIVISION ST             815C
# 1105381        ASSISTED CITIZEN  5400.0   NOLENSVILLE PKE             834C
# 1105382              FALSE CALL  1300.0     RURAL HILL RD             317C
#
#         Sector  Zone  Reporting Area (RPA)  Latitude  Longitude  \
# 1105378      C  13.0                1107.0    36.167    -86.765
# 1105379      C  21.0                4107.0    36.161    -86.778
# 1105380     MT  11.0                6711.0    36.149    -86.797
# 1105381     MT  35.0                8655.0    36.051    -86.714
# 1105382      S  25.0                8861.0    36.056    -86.651
#
#            Mapped Location
# 1105378  (36.167, -86.765)
# 1105379  (36.161, -86.778)
# 1105380  (36.149, -86.797)
# 1105381  (36.051, -86.714)
# 1105382  (36.056, -86.651)

# %%
#3.	How many rows and columns does police_2017 contain?

police_2017.shape
# Out:
# (1105383, 19)

# %%
#4.	Keep just these 12 columns: 

keep_cols = ['Event Number', 'Call Received', 'Shift', 'Tencode', 'Tencode Description', 'Disposition Code', 'Disposition Description', 'Sector', 'Zone', 'Unit Dispatched', 'Latitude', 'Longitude']

police_2017_subset = police_2017[keep_cols]

police_2017_subset.columns
# Out:
# Index(['Event Number', 'Call Received', 'Shift', 'Tencode',
#        'Tencode Description', 'Disposition Code', 'Disposition Description',
#        'Sector', 'Zone', 'Unit Dispatched', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
#5.	Rename the columns above:


police_2017_subset = police_2017_subset.rename(columns = {'Event Number' : 'id' , 'Call Received' : 'call_time' , 'Shift' : 'shift' , 'Unit Dispatched': 'unit','Tencode' : 'tencode' , 'Tencode Description' : 'tencode_desc' , 'Disposition Code' : 'disposition' , 'Disposition Description' : 'disposition_desc', 'Sector' : 'sector' , 'Zone' : 'zone' , 'Latitude' : 'lat' , 'Longitude' : 'lng'})

police_2017_subset.columns
# Out:
# Index(['id', 'call_time', 'shift', 'tencode', 'tencode_desc', 'disposition',
#        'disposition_desc', 'sector', 'zone', 'unit', 'lat', 'lng'],
#       dtype='object')

# %%
#6.	Which unit answered the most calls in 2017? How many calls did they answer?

type_counts = police_2017_subset.unit.value_counts()
type_counts = type_counts.to_frame()
type_counts = type_counts.reset_index()
type_counts.iloc[0]
#most_calls = type_counts.loc[type_counts['unit'].idxmax()]
#df.loc[df['Score'].idxmax()]
#most_calls
# Out:
# index    125C
# unit     5746
# Name: 0, dtype: object

# %%
#7.	How many units answered more than 1000 calls in 2017?


GT1000 = type_counts.loc[type_counts['unit'] > 1000]
#df.loc[df['column_name'] == some_value]
GT1000.describe()

#sum(police_2018.units.value_counts()>1000)
# Out:
#               unit
# count   368.000000
# mean   2343.000000
# std     938.478901
# min    1003.000000
# 25%    1572.750000
# 50%    2253.000000
# 75%    2892.250000
# max    5746.000000

# %%
#8.	What tencode description is associated with the greatest number of calls in 2018?

tendesc = police_2018_subset.tencode_desc.value_counts()
tendesc = tendesc.to_frame()
tendesc = tendesc.reset_index()
tendesc = tendesc.rename(columns = {'index' : 'crime' , 'tencode_desc' : 'count'})
tendesc
#tendesc.iloc[0]
# Out:
#                                           crime   count
# 0                                Business Check  156142
# 1                             Traffic Violation  143257
# 2   Want Officer for Investigation / Assistance  126718
# 3             Administrative/Special Assignment   41765
# 4                   Community Policing Activity   34511
# 5                             Disorderly Person   30139
# 6                             Suspicious Person   28908
# 7            Vehicle Accident - Property Damage   28134
# 8                                         Theft   27392
# 9                                 Safety Hazard   25581
# 10                         Burglary - Residence   19110
# 11                     Burglary - Non-Residence   17610
# 12                 Investigate 911 Hang-Up Call   14125
# 13           Vehicle Accident - Personal Injury    7515
# 14                Vehicle Blocking Right of Way    7510
# 15                              Fight / Assault    6328
# 16                                  Shots Fired    4977
# 17                             Holdup / Robbery    3118
# 18                                   Fixed Post    2770
# 19                                   Meal Break    2687
# 20                               Missing Person    2657
# 21                           Person with Weapon    2626
# 22                   Dangerous / Injured Animal    2421
# 23                              Suicidal Person    2247
# 24                 Transport Prisoner / Suspect    2220
# 25                           Intoxicated Person    1791
# 26                            Corpse / D. O. A.     816
# 27                    Person Indecently Exposed     729
# 28                          Mentally ILL Person     539
# 29                                     Shooting     477
# 30                             Person Screaming     438
# 31                                      Prowler     354
# 32                              Escort / Convoy     346
# 33                                         Fire     345
# 34                              Personal Relief     237
# 35                  Hazardous Liquid / Gas Leak     208
# 36                           Cutting / Stabbing     169
# 37                                   Kidnapping     117
# 38                                 Bank Robbery      94
# 39                                    Explosion      51
# 40                                  Bomb Threat      35
# 41                                Gang Activity      30
# 42                  Personnel in Serious Danger      20
# 43                                     Drowning      19
# 44                           Barricaded Suspect      14
# 45                             Prisoner Escapee       8
# 46                      Riot / Disorderly Crowd       7
# 47                             Active Aggressor       4
# 48                              Occult Activity       4
# 49                             Train Derailment       2
# 50                                       Sniper       1

# %%
#10.	Make a horizontal barplot of the crime counts.

#?plt.barh

plt.barh('crime', 'count', data=tendesc10, color = 'green', edgecolor = 'black');

#plt.barh('type', 'count', data=type_counts, color = 'green', edgecolor = 'black');

# %%
#12.	Since the 2018 data is incomplete, find the latest date for this dataset.  So that comparisons are commensurate, 
#remove rows from the 2013 data that are later than the latest month and day in the 2018 data.


police_2018_subset.head()
#police_2018_subset['call_time'] = pd.to_datetime(police_2018_subset['call_time'])
end_date = police_2018_subset['call_time'].max()
end_date

#'09/21/2018 12:59:58 AM'

police_2013_130921_bool = police_2013_subset['call_time'] <= '09/21/2013 12:59:58 AM'
police_2013_130921 = police_2013_subset.loc[police_2013_130921_bool]
police_2013_130921.tail()

#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
#df = df.loc[mask]

pol2013 = police_2013_130921
pol2018 = police_2018_subset

# %%
#13.	Create subsets of the 2013 and 2018 police call data that includes these five tencodes:
#•	Holdup / Robbery
#•	Bank Robbery
#•	Burglary – Residence
#•	Burglary - Non-Residence
#•	Theft

pol2013.head()
#pol2018.columns

content_check2013 = pol2013.tencode_desc.value_counts()
content_check2013
content_check2018 = pol2018.tencode_desc.value_counts()
content_check2018

#type_counts = police_2013_subset.unit.value_counts()

#pol2013['tencode_desc']

pol2013_five_bool = pol2013.tencode_desc.isin (['Holdup / Robbery' , 'Bank Robbery' ,'Burglary - Residence' , 'Burglary - Non-Residence' , 'Theft'])
pol2013_five_bool.head()
pol2013_five = pol2013.loc[pol2013_five_bool]
pol2013_five.head()
pol2013_five.tencode_desc.value_counts()
#police_2013_130921 = police_2013_subset.loc[police_2013_130921_bool]
#pol2013_five_count = pol2013_five.tencode_desc.value_counts()
#pol2013_five_count


#Data.loc[[‘Andrade’, ‘Veness’]]



#keep_cols = ['Event Number', 'Call Received', 'Complaint Number', 'Shift', 'Tencode', 'Tencode Description', 'Disposition Code', 'Disposition Description', 'Unit Dispatched', 'Sector', 'Zone', 'Latitude', 'Longitude']
#police_2013_subset = police_2013[keep_cols]
#police_2013_subset.columns


pol2018_five_bool = pol2018.tencode_desc.isin (['Holdup / Robbery' , 'Bank Robbery' ,'Burglary - Residence' , 'Burglary - Non-Residence' , 'Theft'])
pol2018_five_bool.head()
pol2018_five = pol2018.loc[pol2018_five_bool]
pol2018_five.head()
pol2018_five.tencode_desc.value_counts()
# Out:
# Theft                       27392
# Burglary - Residence        19110
# Burglary - Non-Residence    17610
# Holdup / Robbery             3118
# Bank Robbery                   94
# Name: tencode_desc, dtype: int64

# %%
#14.	Add a column named ‘year’ to each of these new subset data frames. 
#Set year to 2013 in the 2013 subset and set year to 2018 in the 2018 subset.

pol2013_five2 = pol2013_five
pol2013_five2['year'] = '2013'
pol2013_five2.head()


pol2018_five2 = pol2018_five
pol2018_five2['year'] = '2018'
pol2018_five2.head()



#df['Name'] = 'abc'
# Out:
# C:\Users\Bill\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Bill\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#                 id               call_time  complaint_id shift  tencode  \
# 29  PD201800000032  01/01/2018 12:06:00 AM   20180000124     C       50
# 43  PD201800000048  01/01/2018 12:08:00 AM   20180000351     C       70
# 51  PD201800000058  01/01/2018 12:12:00 AM   20180000134     C       71
# 58  PD201800000066  01/01/2018 12:13:00 AM             0     C       70
# 87  PD201800000097  01/01/2018 12:20:00 AM   20180000126     C       70
#
#                 tencode_desc  disposition          disposition_desc  unit  \
# 29                     Theft            5           GONE ON ARRIVAL  811C
# 43      Burglary - Residence           10               NO RESPONSE  715C
# 51  Burglary - Non-Residence           12  LOCATION/BUILDING SECURE  517C
# 58      Burglary - Residence           11      DISREGARD / SIGNAL 9   NaN
# 87      Burglary - Residence            4          ASSISTED CITIZEN  617C
#
#    sector zone     lat     lng  year
# 29     MT   13  36.150 -86.813  2018
# 43      M   23  36.269 -86.719  2018
# 51      H   17  36.146 -86.662  2018
# 58      M   25  36.279 -86.790  2018
# 87      N   13  36.180 -86.816  2018

# %%
pol2013_five2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62197 entries, 21 to 900583
# Data columns (total 14 columns):
# id                  62197 non-null object
# call_time           62197 non-null object
# complaint_id        62197 non-null int64
# shift               60351 non-null object
# tencode             62197 non-null int64
# tencode_desc        62197 non-null object
# disposition         62197 non-null int64
# disposition_desc    61948 non-null object
# unit                54825 non-null object
# sector              62180 non-null object
# zone                62180 non-null float64
# lat                 62197 non-null float64
# lng                 62197 non-null float64
# year                62197 non-null object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 7.1+ MB

# %%
pol2018_five2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67324 entries, 29 to 747315
# Data columns (total 14 columns):
# id                  67324 non-null object
# call_time           67324 non-null object
# complaint_id        67324 non-null int64
# shift               65348 non-null object
# tencode             67324 non-null int64
# tencode_desc        67324 non-null object
# disposition         67324 non-null int64
# disposition_desc    67313 non-null object
# unit                58369 non-null object
# sector              53254 non-null object
# zone                53275 non-null object
# lat                 53271 non-null float64
# lng                 53271 non-null float64
# year                67324 non-null object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 7.7+ MB

# %%
#15.	Combine the 2013 and 2018 subset data into a single data frame called crimes. Since they have the same columns, 
#you can concatenate the data frames. 
#How many rows and columns are there in the combined data frame?


pol1318 = pd.concat([pol2013_five2, pol2018_five2])
pol1318.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129521 entries, 21 to 747315
# Data columns (total 14 columns):
# id                  129521 non-null object
# call_time           129521 non-null object
# complaint_id        129521 non-null int64
# shift               125699 non-null object
# tencode             129521 non-null int64
# tencode_desc        129521 non-null object
# disposition         129521 non-null int64
# disposition_desc    129261 non-null object
# unit                113194 non-null object
# sector              115434 non-null object
# zone                115455 non-null object
# lat                 115468 non-null float64
# lng                 115468 non-null float64
# year                129521 non-null object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 14.8+ MB

# %%
#16.	Check the value counts for the tencode description in the crimes data. 
#Using the pandas map function, change the descriptions so there are just three categories: 
#Burglary (includes ‘Burglary - Residence' and 'Burglary - Non-Residence'), 
#Robbery (includes 'Bank Robbery' and 'Holdup / Robbery'), and Theft (includes ‘Theft’). 
#Check the value counts again to confirm your changes.

pol1318.tencode_desc.value_counts()
# Out:
# Theft                       49425
# Burglary - Residence        40329
# Burglary - Non-Residence    33556
# Holdup / Robbery             6025
# Bank Robbery                  186
# Name: tencode_desc, dtype: int64

# %%
#16b - continued
#alt - use map instead of replace

#pol1318['tencode_desc'], replace(['aaa', 'bbb'], 'ccc')
pol1318_3 = pol1318
pol1318_3['tencode_desc']=pol1318_3['tencode_desc'].replace(['Burglary - Residence', 'Burglary - Non-Residence'], 'Burglary')
pol1318_3['tencode_desc']=pol1318_3['tencode_desc'].replace(['Bank Robbery', 'Holdup / Robbery'], 'Robbery')
pol1318_3.tencode_desc.value_counts()


#df['BrandName'].replace(['ABC', 'AB'], 'A')
# Out:
# Burglary    73885
# Theft       49425
# Robbery      6211
# Name: tencode_desc, dtype: int64

# %%
pol1318_3.head()
# Out:
#                 id               call_time  complaint_id shift  tencode  \
# 21  PD201300000031  01/01/2013 12:09:00 AM   20130000057     C       70
# 24  PD201300000034  01/01/2013 12:10:00 AM   20130000030     C       71
# 27  PD201300000038  01/01/2013 12:10:00 AM   20130000124     C       70
# 78  PD201300000107  01/01/2013 12:30:00 AM             0     C       50
# 79  PD201300000108  01/01/2013 12:30:00 AM   20130000067     C       70
#
#    tencode_desc  disposition          disposition_desc   unit sector zone  \
# 21     Burglary           13                FALSE CALL   137C      W   37
# 24     Burglary            4          ASSISTED CITIZEN  VANDY      S   21
# 27     Burglary           12  LOCATION/BUILDING SECURE   7F80      M   23
# 78        Theft           11      DISREGARD / SIGNAL 9    NaN      C   25
# 79     Burglary           11      DISREGARD / SIGNAL 9   311C      S   21
#
#        lat     lng  year
# 21  36.056 -86.936  2013
# 24  36.105 -86.762  2013
# 27  36.241 -86.735  2013
# 78  36.160 -86.775  2013
# 79  36.084 -86.748  2013

# %%
#17.	Create a data frame called aggregated_df with the year, crime category, and count of calls 
#for the year and category.


#aggregated_df = pol1318_3.tencode_desc.value_counts()
aggregated_pol1318 = pol1318_3
#aggregated_pol1318.groupby(['year', 'tencode_desc']).size()
#aggregated_pol1318
agg_pol1318 = aggregated_pol1318.groupby(['year', 'tencode_desc']).size()
agg_pol1318b = agg_pol1318.reset_index()
agg_pol1318b.head()
agg_pol1318b.columns = ['year', 'tencode_desc', 'count']
agg_pol1318b
# Out:
#    year tencode_desc  count
# 0  2013     Burglary  37165
# 1  2013      Robbery   2999
# 2  2013        Theft  22033
# 3  2018     Burglary  36720
# 4  2018      Robbery   3212
# 5  2018        Theft  27392

# %%
#18.	Plot a Seaborn facet grid to compare the 2013 and 2018 count of crimes for each category. 
#Has any category changed significantly from 2013 to 2018?

g = sns.FacetGrid(agg_pol1318b, col="year", height=4, aspect=1)
g.map(sns.barplot, "tencode_desc", "count");

print('YTD Theft has increased from 2013 to 2018')
print('Burglary and Robbery have not changed significantly')


#plt.figure(figsize = (10, 8))
#sns.set(style="whitegrid")
#sns.barplot('count', 'type', data = type_counts)
#plt.xlabel('')
#plt.ylabel('')
#plt.title('Types of Public Art in Nashville');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-f224fb32f141> in <module>
#       2 #Has any category changed significantly from 2013 to 2018?
#       3
# ----> 4 g = sns.FacetGrid(agg_pol1318b, col="year", height=4, aspect=1)
#       5 g.map(sns.barplot, "tencode_desc", "count");
#       6
#
# NameError: name 'sns' is not defined

# %%
#intall folium

# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/4f/86/1ab30184cb60bc2b95deffe2bd86b8ddbab65a4fac9f7313c278c6e8d049/folium-0.9.1-py2.py3-none-any.whl (91kB)
# Requirement already satisfied: numpy in c:\users\bill\anaconda3\lib\site-packages (from folium) (1.16.2)
# Requirement already satisfied: requests in c:\users\bill\anaconda3\lib\site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\bill\anaconda3\lib\site-packages (from folium) (2.10)
# Collecting branca>=0.3.0 (from folium)
#   Using cached https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\bill\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\bill\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bill\anaconda3\lib\site-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\bill\anaconda3\lib\site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\bill\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: six in c:\users\bill\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.9.1

# %%
#import folium

import folium

# %%
#19.	Which sector had the least number of calls for 2013? How many calls? What about 2018?

agg_pol1318b
#agg_pol1318b.tencode_desc.min()

#agg_pol1318b[['year','tencode_desc']].min()

agg_pol1318b.groupby(['year', 'tencode_desc']).agg('min')


#df.groupby('A').agg('min')
# Out:
#                    count
# year tencode_desc
# 2013 Burglary      37165
#      Robbery        2999
#      Theft         22033
# 2018 Burglary      36720
#      Robbery        3212
#      Theft         27392

# %%
#23.	Create a folium map of Nashville using [36.1612, -86.7775] as the location to center the map on. 
#Experiment with different values for the zoom_start argument.


nash_map = folium.Map(location = [36.1612, -86.7775], zoom_start = 11.2
                    )
nash_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#24.	You have been asked whether more robberies occur near highways. 
#One theory is that robbers rob near highways so that they can make a speedy getaway. 
#As an initial test of this assumption, map the locations of robberies in your crimes data that have 
#a disposition description of ‘GONE ON ARRIVAL’. 
#First create a subset of the data that contains only the rows of interest. 
#Then create a folium map of locations by building a for-loop and using the iterrows() function 
#to create point locations, and map each point as you loop through your dataframe.

pol2018_five_boolrob = pol2018.tencode_desc.isin (['Holdup / Robbery' , 'Bank Robbery'])
pol2018_five_boolrob.head()
pol2018_five_rob = pol2018.loc[pol2018_five_boolrob]
pol2018_five_rob.head()
rob2018 = pol2018_five_rob

rob2018.head()
# keep disposition = 5

rob2018_boolrob = rob2018.disposition.isin ([5])
rob2018_boolrob.head()
disregard2018 = rob2018.loc[rob2018_boolrob]
disregard2018.head()



nash_map = folium.Map(location = [36.1612, -86.7775], zoom_start = 11.2)


disregard2018.isnull().sum()
disregard2018=disregard2018.dropna(subset = ['lat', 'lng'])


                      
for ind, row in disregard2018.iterrows():
    point = [row['lat'], row['lng']]
    folium.Marker(point).add_to(nash_map)

nash_map.save("folium_2018.html")
                      
#rob2018.head()
                      

#for ind, row in art.iterrows():
#    point = [row['Latitude'], row['Longitude']]
#    folium.Marker(point).add_to(nash_map)

# %%
#24.	for 2013

pol2013_five_boolrob = pol2013.tencode_desc.isin (['Holdup / Robbery' , 'Bank Robbery'])
pol2013_five_boolrob.head()
pol2013_five_rob = pol2013.loc[pol2013_five_boolrob]
pol2013_five_rob.head()
rob2013 = pol2013_five_rob

rob2013.head()
# keep disposition = 5

rob2013_boolrob = rob2013.disposition.isin ([5])
rob2013_boolrob.head()
disregard2013 = rob2013.loc[rob2013_boolrob]
disregard2013.head()



nash_map = folium.Map(location = [36.1612, -86.7775], zoom_start = 11.2)


disregard2013.isnull().sum()
disregard2013=disregard2013.dropna(subset = ['lat', 'lng'])


                      
for ind, row in disregard2013.iterrows():
    point = [row['lat'], row['lng']]
    folium.Marker(point).add_to(nash_map)

nash_map.save("folium_2013.html")
                      
#rob2018.head()
                      

#for ind, row in art.iterrows():
#    point = [row['Latitude'], row['Longitude']]
#    folium.Marker(point).add_to(nash_map)

# %%
#25.	Another theory says that more burglaries occurs on rainy days. 
#Weather data is available in a SQLite database file called weather.db.

db = '../data/weather.db'
con = sql.connect(db)
mycursor = con.cursor() 
mycursor.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
tables=(mycursor.fetchall())
print(tables)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-208722c03686> in <module>
#       3
#       4 db = '../data/weather.db'
# ----> 5 con = sql.connect(db)
#       6 mycursor = con.cursor()
#       7 mycursor.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
#
# NameError: name 'sql' is not defined

# %%
mycursor.execute("SELECT * FROM weather2013;")

weather_data_2013 = (mycursor.fetchall())
weather_data_2013
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-2fa8edbdc2b8> in <module>
# ----> 1 mycursor.execute("SELECT * FROM weather2013;")
#       2
#       3 weather_data_2013 = (mycursor.fetchall())
#       4 weather_data_2013
#
# NameError: name 'mycursor' is not defined

# %%
weather_2013_df = pd.read_sql_query("SELECT * FROM weather2013;", con)

weather_2013_df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-dda4f86caf4e> in <module>
# ----> 1 weather_2013_df = pd.read_sql_query("SELECT * FROM weather2013;", con)
#       2
#       3 weather_2013_df.describe()
#
# NameError: name 'con' is not defined

# %%
#26.	Plot the unique weather stations on a map. Choose the one you think is closest to the city center. 
#Filter the 2013 weather data to grab only the rows for this station.

weather_2013_df.isnull().sum()
weather_2013_df=weather_2013_df.dropna(subset = ['lat', 'lng'])
weather_2013_df.head()
#unique_sta_2013 = weather_2013_df['name'].unique().tolist()

#unique_sta_2013_df = pd.DataFrame(unique_sta_2013)
#unique_sta_2013_df

unique_stations = weather_2013_df.drop_duplicates(subset=['name'])
unique_stations.describe()

nash_map = folium.Map(location = [36.1612, -86.7775], zoom_start = 11.2)


unique_stations.isnull().sum()
unique_stations=unique_stations.dropna(subset = ['lat', 'lng'])


                      
for ind, row in unique_stations.iterrows():
    point = [row['lat'], row['lng']]
    folium.Marker(point).add_to(nash_map)

nash_map.save("weather_sta.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-abd4713e9b15> in <module>
#       2 #Filter the 2013 weather data to grab only the rows for this station.
#       3
# ----> 4 weather_2013_df.isnull().sum()
#       5 weather_2013_df=weather_2013_df.dropna(subset = ['lat', 'lng'])
#       6 weather_2013_df.head()
#
# NameError: name 'weather_2013_df' is not defined

# %%
#to find closest stations to Nashville

unique_stations.head()
uniq_compare_lat = unique_stations
uniq_compare_lat.columns

uniq_compare_lat.to_numeric(uniq_compare_lat[lat])


#uniq_compare_lat["lat_dif"] = (36.1612-uniq_compare_lat['lat'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-c8f947f789c7> in <module>
#       1 #to find closest stations to Nashville
#       2
# ----> 3 unique_stations.head()
#       4 uniq_compare_lat = unique_stations
#       5 uniq_compare_lat.columns
#
# NameError: name 'unique_stations' is not defined

# %%
uniq_compare_lat.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-6bb2b56124ce> in <module>
# ----> 1 uniq_compare_lat.info()
#
# NameError: name 'uniq_compare_lat' is not defined

# %%
# convert lat and lgn fromn string to numeric, diff for lat and lng, abs value, add, find min
